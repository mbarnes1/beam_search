# %%
from beam import BeamSearch
from functools import partial
from itertools import izip, repeat
import sys
import time
sys.path.append('../coco-caption')
sys.path.append('../show-attend-and-tell-tensorflow')
from core.utils import load_pickle
from pycocoevalcap.bleu.bleu import Bleu

# %% [markdown]
# ## Load data

# %%
split = 'train'
word_to_idx = load_pickle('../show-attend-and-tell-tensorflow/data/train/word_to_idx.pkl')
words = word_to_idx.keys()
words.remove('<START>')
words.remove('<END>')
words.remove('<NULL>')
words.append('.')
references = load_pickle('../show-attend-and-tell-tensorflow/data/{}/{}.references.pkl'.format(split, split))
# Out:
# Loaded ../show-attend-and-tell-tensorflow/data/train/word_to_idx.pkl..
# Loaded ../show-attend-and-tell-tensorflow/data/train/train.references.pkl..

# %% [markdown]
# ## Score function

# %%
scorer = Bleu(n=4)

def score(hypotheses, reference_sequences):
    """
    Score each hypothesis. Any sequence in reference_sequences is correct.
    Returns the best score for each hypothesis, among the reference_sequences.
    :param hypotheses: Dict of hypotheses to compute score.
    :param reference_sequences: List of ground truth sequences.
    :return scores: Dict with same keys as hypotheses, but with score as value
    """
    #hypotheses = dict(izip(xrange(0, len(hypotheses)), hypotheses))
    reference_sequences = dict(izip(hypotheses.iterkeys(), repeat(reference_sequences, len(hypotheses))))
    _, scores = scorer.compute_score(reference_sequences, hypotheses)
    return scores

# %% [markdown]
# ## Beam Search
# #### with reference actions
# Reference words are as good, or better than, non-reference words in terms of BLEU score. Only a handful (~50) reference words to consider, but potentially 10k+ non-reference words. So by only considering the reference words as the set of actions available to expert, beam search is dramatically faster and produces the same results.
#
# ~0.5s per search with reference word actions

# %%
start_time = time.time()
n_beams = 5
n_searches = 2
for counter, (_, reference) in enumerate(references.iteritems()):
    if counter >= n_searches:
        break

    print 'Ground truth:\n \t', '\n \t'.join(reference)
    score_wrapper = partial(score, reference_sequences=reference)
    reference_words = set()
    for sentence in reference:
        reference_words.update(sentence.split(' '))
    beam_search = BeamSearch(n_beams, score_wrapper, reference_words)
    initial_beams = [[sentence.split(' ')[0]] for sentence in reference]
    scores, sequence = beam_search.search(max_length=15, beams=initial_beams)

end_time = time.time()
print ' \n Elapsed time per search: {}s \n \n'.format(float(end_time - start_time) / n_searches)
# Out:
# Ground truth:
#  	closeup of bins of food that include broccoli and bread .
#  	a meal is presented in brightly colored plastic trays .
#  	there are containers filled with different kinds of foods .
#  	a bunch of trays that have different food .
#  	colorful dishes holding meat vegetables fruit and bread .
# {'reflen': 1620, 'guess': [355, 175, 0, 0], 'testlen': 355, 'correct': [350, 7, 0, 0]}
# ratio: 0.219135802469
# Beam length 2
#  	3.01973833959e-05: closeup of
#  	3.01973833959e-05: a bunch
#  	3.01973833959e-05: a meal
#  	3.01973833959e-05: there are
#  	3.01973833959e-05: a bunch
# {'reflen': 1575, 'guess': [525, 350, 175, 0], 'testlen': 525, 'correct': [516, 183, 5, 0]}
# ratio: 0.333333333333
# Beam length 3
#  	0.00427967742473: closeup of bins
#  	0.00427967742473: a bunch of
#  	0.00427967742473: a meal is
#  	0.00427967742473: there are containers
#  	0.00427967742473: a bunch of
# {'reflen': 1575, 'guess': [700, 525, 350, 175], 'testlen': 700, 'correct': [688, 361, 180, 5]}
# ratio: 0.444444444444
# Beam length 4
#  	0.286504796639: closeup of bins of
#  	0.286504796639: a bunch of trays
#  	0.286504796639: a meal is presented
#  	0.286504796639: there are containers filled
#  	0.286504796639: a bunch of trays
# {'reflen': 1575, 'guess': [875, 700, 525, 350], 'testlen': 875, 'correct': [858, 534, 355, 180]}
# ratio: 0.555555555555
# Beam length 5
#  	0.449328963883: closeup of bins of food
#  	0.449328963883: a bunch of trays that
#  	0.449328963883: a meal is presented in
#  	0.449328963883: there are containers filled with
#  	0.449328963883: a bunch of trays that
# {'reflen': 1575, 'guess': [1050, 875, 700, 525], 'testlen': 1050, 'correct': [1028, 708, 530, 355]}
# ratio: 0.666666666666
# Beam length 6
#  	0.606530659467: closeup of bins of food that
#  	0.606530659467: a bunch of trays that have
#  	0.606530659467: a meal is presented in brightly
#  	0.606530659467: there are containers filled with different
#  	0.606530659467: a bunch of trays that have
# {'reflen': 1575, 'guess': [1225, 1050, 875, 700], 'testlen': 1225, 'correct': [1198, 882, 705, 530]}
# ratio: 0.777777777777
# Beam length 7
#  	0.751477292825: closeup of bins of food that include
#  	0.751477292825: a bunch of trays that have different
#  	0.751477292825: a meal is presented in brightly colored
#  	0.751477292825: there are containers filled with different kinds
#  	0.751477292825: a bunch of trays that have different
# {'reflen': 1575, 'guess': [1400, 1225, 1050, 875], 'testlen': 1400, 'correct': [1368, 1057, 880, 705]}
# ratio: 0.888888888888
# Beam length 8
#  	0.882496902334: closeup of bins of food that include broccoli
#  	0.882496902334: a bunch of trays that have different food
#  	0.882496902334: a meal is presented in brightly colored plastic
#  	0.882496902334: there are containers filled with different kinds of
#  	0.882496902334: a bunch of trays that have different food
# {'reflen': 1575, 'guess': [1575, 1400, 1225, 1050], 'testlen': 1575, 'correct': [1539, 1235, 1055, 880]}
# ratio: 0.999999999999
# Beam length 9
#  	0.999999999752: closeup of bins of food that include broccoli and
#  	0.999999999752: a bunch of trays that have different food .
#  	0.999999999752: a meal is presented in brightly colored plastic trays
#  	0.999999999752: there are containers filled with different kinds of foods
#  	0.999999999752: a bunch of trays that have different food .
# {'reflen': 1068, 'guess': [1068, 961, 854, 747], 'testlen': 1068, 'correct': [1043, 860, 752, 645]}
# ratio: 0.999999999999
# Beam length 10
#  	0.99999999978: closeup of bins of food that include broccoli and bread
#  	0.99999999978: a meal is presented in brightly colored plastic trays .
#  	0.99999999978: there are containers filled with different kinds of foods .
#  	0.999999999752: a bunch of trays that have different food .
#  	0.999999999752: a bunch of trays that have different food .
# {'reflen': 423, 'guess': [423, 384, 345, 306], 'testlen': 423, 'correct': [414, 350, 311, 272]}
# ratio: 0.999999999998
# Beam length 11
#  	0.999999999802: closeup of bins of food that include broccoli and bread .
#  	0.99999999978: a meal is presented in brightly colored plastic trays .
#  	0.99999999978: there are containers filled with different kinds of foods .
#  	0.999999999752: a bunch of trays that have different food .
#  	0.999999999752: a bunch of trays that have different food .
# Ground truth:
#  	a giraffe standing next to a forest filled with trees .
#  	a giraffe mother with its baby in the forest .
#  	two giraffes standing in a tree filled area .
#  	a giraffe standing up nearby a tree .
#  	a giraffe eating food from the top of the tree .
# {'reflen': 1080, 'guess': [265, 130, 0, 0], 'testlen': 265, 'correct': [264, 13, 0, 0]}
# ratio: 0.24537037037
# Beam length 2
#  	4.97870683243e-05: a forest
#  	4.97870683243e-05: a giraffe
#  	4.97870683243e-05: a tree
#  	4.97870683243e-05: a forest
#  	4.97870683243e-05: a giraffe
# {'reflen': 1040, 'guess': [390, 260, 130, 0], 'testlen': 390, 'correct': [385, 142, 10, 0]}
# ratio: 0.375
# Beam length 3
#  	0.00597277098931: a forest filled
#  	0.00597277098931: a giraffe standing
#  	0.00597277098931: a giraffe eating
#  	0.00597277098931: a giraffe mother
#  	0.00597277098931: a tree .
# {'reflen': 840, 'guess': [419, 314, 209, 104], 'testlen': 419, 'correct': [411, 217, 110, 5]}
# ratio: 0.498809523809
# Beam length 4
#  	0.367879440888: a forest filled with
#  	0.367879440888: a giraffe standing next
#  	0.367879440888: a giraffe standing up
#  	0.367879440888: a giraffe eating food
#  	0.367879440888: a giraffe mother with
# {'reflen': 1040, 'guess': [650, 520, 390, 260], 'testlen': 650, 'correct': [635, 397, 265, 135]}
# ratio: 0.624999999999
# Beam length 5
#  	0.548811635808: a forest filled with trees
#  	0.548811635808: a giraffe standing next to
#  	0.548811635808: a giraffe standing up nearby
#  	0.548811635808: a giraffe eating food from
#  	0.548811635808: a giraffe mother with its
# {'reflen': 1040, 'guess': [780, 650, 520, 390], 'testlen': 780, 'correct': [760, 525, 395, 265]}
# ratio: 0.749999999999
# Beam length 6
#  	0.716531310284: a forest filled with trees .
#  	0.716531310284: a giraffe standing next to a
#  	0.716531310284: a giraffe standing up nearby a
#  	0.716531310284: a giraffe eating food from the
#  	0.716531310284: a giraffe mother with its baby
# {'reflen': 840, 'guess': [734, 629, 524, 419], 'testlen': 734, 'correct': [715, 533, 424, 319]}
# ratio: 0.873809523808
# Beam length 7
#  	0.866877899462: a giraffe standing next to a forest
#  	0.866877899462: a giraffe standing up nearby a tree
#  	0.866877899462: a giraffe eating food from the top
#  	0.866877899462: a giraffe mother with its baby in
#  	0.762949413683: a giraffe standing next to a tree
# {'reflen': 1040, 'guess': [1040, 910, 780, 650], 'testlen': 1040, 'correct': [1011, 789, 631, 498]}
# ratio: 0.999999999999
# Beam length 8
#  	0.999999999716: a giraffe standing next to a forest filled
#  	0.999999999716: a giraffe standing up nearby a tree .
#  	0.999999999716: a giraffe eating food from the top of
#  	0.999999999716: a giraffe mother with its baby in the
#  	0.945741608735: a giraffe standing up nearby a tree filled
# {'reflen': 944, 'guess': [944, 839, 734, 629], 'testlen': 944, 'correct': [918, 743, 634, 503]}
# ratio: 0.999999999999
# Beam length 9
#  	0.999999999752: a giraffe standing next to a forest filled with
#  	0.999999999752: a giraffe eating food from the top of the
#  	0.999999999752: a giraffe mother with its baby in the forest
#  	0.999999999716: a giraffe standing up nearby a tree .
#  	0.955442791968: a giraffe standing up nearby a tree filled area
# {'reflen': 1048, 'guess': [1048, 943, 838, 733], 'testlen': 1048, 'correct': [1018, 846, 738, 607]}
# ratio: 0.999999999999
# Beam length 10
#  	0.99999999978: a giraffe standing next to a forest filled with trees
#  	0.99999999978: a giraffe eating food from the top of the tree
#  	0.99999999978: a giraffe mother with its baby in the forest .
#  	0.999999999716: a giraffe standing up nearby a tree .
#  	0.962195457984: a giraffe standing up nearby a tree filled area .
# {'reflen': 600, 'guess': [600, 545, 490, 435], 'testlen': 600, 'correct': [583, 496, 440, 384]}
# ratio: 0.999999999998
# Beam length 11
#  	0.999999999802: a giraffe standing next to a forest filled with trees .
#  	0.999999999802: a giraffe eating food from the top of the tree .
#  	0.99999999978: a giraffe mother with its baby in the forest .
#  	0.999999999716: a giraffe standing up nearby a tree .
#  	0.962195457984: a giraffe standing up nearby a tree filled area .
#
#  Elapsed time per search: 0.505202531815s

# %% [markdown]
# #### With all actions
# ~360s per search with reference word actions

# %%
start_time = time.time()
n_beams = 5
n_searches = 2
for counter, (_, reference) in enumerate(references.iteritems()):
    if counter >= n_searches:
        break

    print 'Ground truth:\n \t', '\n \t'.join(reference)
    score_wrapper = partial(score, reference_sequences=reference)
    beam_search = BeamSearch(n_beams, score_wrapper, words)
    initial_beams = [[sentence.split(' ')[0]] for sentence in reference]
    scores, sequence = beam_search.search(max_length=15, beams=initial_beams)

end_time = time.time()
print ' \n Elapsed time per search: {}s \n \n'.format(float(end_time - start_time) / n_searches)
# Out:
# Ground truth:
#  	closeup of bins of food that include broccoli and bread .
#  	a meal is presented in brightly colored plastic trays .
#  	there are containers filled with different kinds of foods .
#  	a bunch of trays that have different food .
#  	colorful dishes holding meat vegetables fruit and bread .
# {'reflen': 1039905, 'guess': [231085, 115540, 0, 0], 'testlen': 231085, 'correct': [115715, 7, 0, 0]}
# ratio: 0.222217414091
# Beam length 2
#  	3.01973833959e-05: closeup of
#  	3.01973833959e-05: a bunch
#  	3.01973833959e-05: a meal
#  	3.01973833959e-05: there are
#  	3.01973833959e-05: a bunch
# {'reflen': 1039860, 'guess': [346620, 231080, 115540, 0], 'testlen': 346620, 'correct': [231246, 115548, 5, 0]}
# ratio: 0.333333333333
# Beam length 3
#  	0.00427967742473: closeup of bins
#  	0.00427967742473: a bunch of
#  	0.00427967742473: a meal is
#  	0.00427967742473: there are containers
#  	0.00427967742473: a bunch of
# {'reflen': 1039860, 'guess': [462160, 346620, 231080, 115540], 'testlen': 462160, 'correct': [346783, 231091, 115545, 5]}
# ratio: 0.444444444444
# Beam length 4
#  	0.286504796639: closeup of bins of
#  	0.286504796639: a bunch of trays
#  	0.286504796639: a meal is presented
#  	0.286504796639: there are containers filled
#  	0.286504796639: a bunch of trays
# {'reflen': 1039860, 'guess': [577700, 462160, 346620, 231080], 'testlen': 577700, 'correct': [462318, 346629, 231085, 115545]}
# ratio: 0.555555555556
# Beam length 5
#  	0.449328963883: closeup of bins of food
#  	0.449328963883: a bunch of trays that
#  	0.449328963883: a meal is presented in
#  	0.449328963883: there are containers filled with
#  	0.449328963883: a bunch of trays that
# {'reflen': 1039860, 'guess': [693240, 577700, 462160, 346620], 'testlen': 693240, 'correct': [577853, 462168, 346625, 231085]}
# ratio: 0.666666666667
# Beam length 6
#  	0.606530659467: closeup of bins of food that
#  	0.606530659467: a bunch of trays that have
#  	0.606530659467: a meal is presented in brightly
#  	0.606530659467: there are containers filled with different
#  	0.606530659467: a bunch of trays that have
# {'reflen': 1039860, 'guess': [808780, 693240, 577700, 462160], 'testlen': 808780, 'correct': [693388, 577707, 462165, 346625]}
# ratio: 0.777777777778
# Beam length 7
#  	0.751477292825: closeup of bins of food that include
#  	0.751477292825: a bunch of trays that have different
#  	0.751477292825: a meal is presented in brightly colored
#  	0.751477292825: there are containers filled with different kinds
#  	0.751477292825: a bunch of trays that have different
# {'reflen': 1039860, 'guess': [924320, 808780, 693240, 577700], 'testlen': 924320, 'correct': [808923, 693247, 577705, 462165]}
# ratio: 0.888888888889
# Beam length 8
#  	0.882496902334: closeup of bins of food that include broccoli
#  	0.882496902334: a bunch of trays that have different food
#  	0.882496902334: a meal is presented in brightly colored plastic
#  	0.882496902334: there are containers filled with different kinds of
#  	0.882496902334: a bunch of trays that have different food
# {'reflen': 1039860, 'guess': [1039860, 924320, 808780, 693240], 'testlen': 1039860, 'correct': [924459, 808790, 693245, 577705]}
# ratio: 1.0
# Beam length 9
#  	0.999999999752: closeup of bins of food that include broccoli and
#  	0.999999999752: a bunch of trays that have different food .
#  	0.999999999752: a meal is presented in brightly colored plastic trays
#  	0.999999999752: there are containers filled with different kinds of foods
#  	0.999999999752: a bunch of trays that have different food .
# {'reflen': 693258, 'guess': [693258, 623932, 554606, 485280], 'testlen': 693258, 'correct': [624014, 554612, 485285, 415959]}
# ratio: 1.0
# Beam length 10
#  	0.99999999978: closeup of bins of food that include broccoli and bread
#  	0.99999999978: a meal is presented in brightly colored plastic trays .
#  	0.99999999978: there are containers filled with different kinds of foods .
#  	0.999999999752: a bunch of trays that have different food .
#  	0.999999999752: a bunch of trays that have different food .
# {'reflen': 254226, 'guess': [254226, 231114, 208002, 184890], 'testlen': 254226, 'correct': [231144, 208007, 184895, 161783]}
# ratio: 1.0
# Beam length 11
#  	0.999999999802: closeup of bins of food that include broccoli and bread .
#  	0.99999999978: a meal is presented in brightly colored plastic trays .
#  	0.99999999978: there are containers filled with different kinds of foods .
#  	0.999999999752: a bunch of trays that have different food .
#  	0.999999999752: a bunch of trays that have different food .
# Ground truth:
#  	a giraffe standing next to a forest filled with trees .
#  	a giraffe mother with its baby in the forest .
#  	two giraffes standing in a tree filled area .
#  	a giraffe standing up nearby a tree .
#  	a giraffe eating food from the top of the tree .
# {'reflen': 924360, 'guess': [231085, 115540, 0, 0], 'testlen': 231085, 'correct': [115674, 13, 0, 0]}
# ratio: 0.249994590852
# Beam length 2
#  	4.97870683243e-05: a giraffe
#  	4.97870683243e-05: a tree
#  	4.97870683243e-05: a forest
#  	4.97870683243e-05: a giraffe
#  	4.97870683243e-05: a tree
# {'reflen': 924320, 'guess': [346620, 231080, 115540, 0], 'testlen': 346620, 'correct': [231205, 115552, 11, 0]}
# ratio: 0.375
# Beam length 3
#  	0.00597277098931: a giraffe standing
#  	0.00597277098931: a giraffe mother
#  	0.00597277098931: a giraffe eating
#  	0.00597277098931: a tree filled
#  	0.00597277098931: a tree .
# {'reflen': 739464, 'guess': [369731, 277298, 184865, 92432], 'testlen': 369731, 'correct': [277395, 184873, 92438, 5]}
# ratio: 0.499998647669
# Beam length 4
#  	0.367879440888: a giraffe standing next
#  	0.367879440888: a giraffe standing up
#  	0.367879440888: a giraffe mother with
#  	0.367879440888: a giraffe eating food
#  	0.367879440888: a tree filled area
# {'reflen': 924320, 'guess': [577700, 462160, 346620, 231080], 'testlen': 577700, 'correct': [462275, 346626, 231085, 115545]}
# ratio: 0.625
# Beam length 5
#  	0.548811635808: a giraffe standing next to
#  	0.548811635808: a giraffe standing up nearby
#  	0.548811635808: a giraffe mother with its
#  	0.548811635808: a giraffe eating food from
#  	0.548811635808: a tree filled area .
# {'reflen': 739464, 'guess': [554597, 462164, 369731, 277298], 'testlen': 554597, 'correct': [462253, 369736, 277303, 184870]}
# ratio: 0.749998647669
# Beam length 6
#  	0.716531310284: a giraffe standing next to a
#  	0.716531310284: a giraffe standing up nearby a
#  	0.716531310284: a giraffe mother with its baby
#  	0.716531310284: a giraffe eating food from the
#  	0.569836377314: a giraffe standing next to baby
# {'reflen': 924320, 'guess': [808780, 693240, 577700, 462160], 'testlen': 808780, 'correct': [693346, 554601, 439056, 323516]}
# ratio: 0.875
# Beam length 7
#  	0.866877899462: a giraffe standing next to a forest
#  	0.866877899462: a giraffe standing up nearby a tree
#  	0.866877899462: a giraffe mother with its baby in
#  	0.866877899462: a giraffe eating food from the top
#  	0.762949413683: a giraffe standing next to a tree
# {'reflen': 924320, 'guess': [924320, 808780, 693240, 577700], 'testlen': 924320, 'correct': [808881, 693249, 554599, 439056]}
# ratio: 1.0
# Beam length 8
#  	0.999999999716: a giraffe standing next to a forest filled
#  	0.999999999716: a giraffe standing up nearby a tree .
#  	0.999999999716: a giraffe mother with its baby in the
#  	0.999999999716: a giraffe eating food from the top of
#  	0.945741608735: a giraffe standing up nearby a tree filled
# {'reflen': 831896, 'guess': [831896, 739463, 647030, 554597], 'testlen': 831896, 'correct': [739542, 647039, 554602, 439061]}
# ratio: 1.0
# Beam length 9
#  	0.999999999752: a giraffe standing next to a forest filled with
#  	0.999999999752: a giraffe mother with its baby in the forest
#  	0.999999999752: a giraffe eating food from the top of the
#  	0.999999999716: a giraffe standing up nearby a tree .
#  	0.955442791968: a giraffe standing up nearby a tree filled area
# {'reflen': 924328, 'guess': [924328, 831895, 739462, 647029], 'testlen': 924328, 'correct': [831970, 739470, 647034, 531493]}
# ratio: 1.0
# Beam length 10
#  	0.99999999978: a giraffe standing next to a forest filled with trees
#  	0.99999999978: a giraffe mother with its baby in the forest .
#  	0.99999999978: a giraffe eating food from the top of the tree
#  	0.999999999716: a giraffe standing up nearby a tree .
#  	0.962195457984: a giraffe standing up nearby a tree filled area .
# {'reflen': 508404, 'guess': [508404, 462185, 415966, 369747], 'testlen': 508404, 'correct': [462223, 415972, 369752, 323532]}
# ratio: 1.0
# Beam length 11
#  	0.999999999802: a giraffe standing next to a forest filled with trees .
#  	0.999999999802: a giraffe eating food from the top of the tree .
#  	0.99999999978: a giraffe mother with its baby in the forest .
#  	0.999999999716: a giraffe standing up nearby a tree .
#  	0.962195457984: a giraffe standing up nearby a tree filled area .
#
#  Elapsed time per search: 362.784044504s
